# %%
import shutil

if not shutil.which("pdflatex"):
    raise RuntimeError("pdflatex not installed")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 4
#       1 import shutil
#       3 if not shutil.which("pdflatex"):
# ----> 4     raise RuntimeError("pdflatex not installed")
#
# RuntimeError: pdflatex not installed
